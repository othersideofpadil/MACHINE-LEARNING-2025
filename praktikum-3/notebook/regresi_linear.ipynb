# %%
## studi kasus regresi linear sederhana

# %%
# load data

# %%
import pandas as pd

#buat data frame
df = pd.read_csv("../data/socr.csv", sep = ",")
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
## pre proses data
df1 = (
    df[["Height(Inches)", "Weight(Pounds)"]]
    .rename(columns = { "Height(Inches)" : "tinggi_cm",
                        "Weight(Pounds)" : "berat_kg"})
    .assign(
        tinggi_cm = lambda d: d["tinggi_cm"] * 2.54,
        berat_kg = lambda d: d["berat_kg"] * 0.45359237
    )
    .round({"tinggi_cm" : 2, "berat_kg" : 2})
).copy()

df1.head()
# Out:
#    tinggi_cm  berat_kg
# 0     167.09     51.25
# 1     181.65     61.91
# 2     176.27     69.41
# 3     173.27     64.56
# 4     172.18     65.45

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1[["tinggi_cm"]]
y = df1 [["berat_kg"]]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state = 7
)

print('Jumlah data training ', len(x_train))
print('Jumlah data testing', len(x_test))
# Out:
# Jumlah data training  20000
# Jumlah data testing 5000

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Prediksi data uji
y_pred = model.predict(x_test)

# Hitung metrik evaluasi
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)  # default squared=True
rmse = np.sqrt(mse)

# Tampilkan hasil
print("Koefisien (kg per cm):", model.coef_[0])
print("Intersep (kg):", model.intercept_)
print("R2 (test):", r2)
print("MAE (kg):", mae)
print("MSE (kg²):", mse)
print("RMSE (kg):", rmse)
# Out:
# Koefisien (kg per cm): [0.55182326]
# Intersep (kg): [-37.65708878]
# R2 (test): 0.24989263013277574
# MAE (kg): 3.670410789894354
# MSE (kg²): 21.242937601397227
# RMSE (kg): 4.609006140308042

# %%
slope = float(model.coef_[0])
intercept = float(model.intercept_)
print(f"Persamaan : y = {slope:.3f} * x + {intercept:.3f}")
# Out:
# Persamaan : y = 0.552 * x + -37.657
# C:\Users\yudhi\AppData\Local\Temp\ipykernel_7980\1680934378.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   slope = float(model.coef_[0])
# C:\Users\yudhi\AppData\Local\Temp\ipykernel_7980\1680934378.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   intercept = float(model.intercept_)
